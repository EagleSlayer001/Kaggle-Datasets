# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/16k_Movies.csv.zip')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-cf8bb4878022> in <cell line: 1>()
# ----> 1 df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/16k_Movies.csv.zip')
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
#renaming df movie_info to help me keep conceptualize the information
movie_info = df

# %%
#checking the new df name represents the same df
movie_info.head()

# %%
#When looking at the genres, there are several categories listed in on cell
#I want to make it easier to work with the given information to make connections
print(movie_info['Genres'])

# %%
g = len(pd.unique(movie_info['Genres']))
print("Number of Genres:", g)
# Out:
# Number of Genres: 1664

# %%
#So, I needed to generalize the Genre section by creating an additional
# column cataegory, "New Genres", that takes just the first item in the cell
# This is an assumption on my part that the first listed genre descritor in the cell
# is the main overarching genre
    #A movie may be a Drama, Mystery, Romance, but the prominent defining
    # characteristic of the movie would be that it is a Drama
df["New Genres"] = movie_info['Genres'].apply(lambda x: x.split(',')[0] if isinstance(x, str) else None)

# %%
# Now I have the attribute New Genres that list each movies' genre with
# only one classification
print(movie_info['New Genres'])
# Out:
# 0              Drama
# 1              Drama
# 2              Drama
# 3              Drama
# 4              Drama
#             ...
# 16285          Drama
# 16286    Documentary
# 16287    Documentary
# 16288    Documentary
# 16289    Documentary
# Name: New Genres, Length: 16290, dtype: object

# %%
# Making sure all the attributes are correct
print(movie_info.columns)
# Out:
# Index(['Unnamed: 0', 'Title', 'Release Date', 'Description', 'Rating',
#        'No of Persons Voted', 'Directed by', 'Written by', 'Duration',
#        'Genres', 'New Genres'],
#       dtype='object')

# %%
# Checking .head() to make sure the info is still correct
movie_info.head()
# Out:
#    Unnamed: 0                     Title  Release Date  \
# 0           0            Dekalog (1988)  Mar 22, 1996
# 1           1         Three Colors: Red  Nov 23, 1994
# 2           2            The Conformist  Oct 22, 1970
# 3           3               Tokyo Story  Mar 13, 1972
# 4           4  The Leopard (re-release)  Aug 13, 2004
#
#                                          Description  Rating  \
# 0  This masterwork by Krzysztof Kieślowski is one...     7.4
# 1  Krzysztof Kieslowski closes his Three Colors t...     8.3
# 2  Set in Rome in the 1930s, this re-release of B...     7.3
# 3  Yasujiro Ozu’s Tokyo Story follows an aging co...     8.1
# 4  Set in Sicily in 1860, Luchino Visconti's spec...     7.8
#
#   No of Persons Voted           Directed by  \
# 0                 118  Krzysztof Kieslowski
# 1                 241  Krzysztof Kieslowski
# 2                 106   Bernardo Bertolucci
# 3                 147          Yasujirô Ozu
# ...
